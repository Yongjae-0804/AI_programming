# %% [markdown]
# AI 프로그래밍 기말고사 2번
# 데이터셋 링크
# https://drive.google.com/drive/folders/1gVksn7jKwZ9qpIlWRIdD0lsO4FUeqCdK

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# 패키지
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D
from sklearn.model_selection import train_test_split, KFold
from tensorflow.keras.layers import Embedding
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing.text import text_to_word_sequence, Tokenizer
from sklearn.preprocessing import StandardScaler, MinMaxScaler

import tensorflow.keras.datasets.mnist as mnist

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import sys

import matplotlib.pyplot as plt
import numpy as np
from tensorflow.keras.datasets import mnist
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.layers import Embedding
from tensorflow.keras.preprocessing.sequence import pad_sequences

import sys
import os
from sklearn.model_selection import train_test_split
from PIL import Image
import os, glob
from tensorflow.keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ReduceLROnPlateau

# %%
# %cd /content/drive/MyDrive/Colab Notebooks/data/
# !unzip aip_final_q2.zip
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
#   inflating: cards/train/jack of spades/146.jpg
#   inflating: cards/train/jack of spades/147.jpg
#   inflating: cards/train/jack of spades/148.jpg
#   inflating: cards/train/jack of spades/149.jpg
#   inflating: cards/train/jack of spades/150.jpg
#   inflating: cards/train/jack of spades/151.jpg
#   inflating: cards/train/jack of spades/152.jpg
#   inflating: cards/train/jack of spades/153.jpg
#   inflating: cards/train/jack of spades/154.jpg
#   inflating: cards/train/jack of spades/155.jpg
#   inflating: cards/train/jack of spades/156.jpg
#   inflating: cards/train/jack of spades/157.jpg
#   inflating: cards/train/jack of spades/158.jpg
#   inflating: cards/train/jack of spades/159.jpg
#   inflating: cards/train/jack of spades/160.jpg
#   inflating: cards/train/jack of spades/161.jpg
#   inflating: cards/train/jack of spades/162.jpg
#   inflating: cards/train/jack of spades/163.jpg
#   inflating: cards/train/jack of spades/164.jpg
# ...

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/data/cards/cards.csv')

# %%
df.head()
# Out:
#    class index                   filepaths        labels card type data set
# 0            0  train/ace of clubs/001.jpg  ace of clubs       ace    train
# 1            0  train/ace of clubs/002.jpg  ace of clubs       ace    train
# 2            0  train/ace of clubs/003.jpg  ace of clubs       ace    train
# 3            0  train/ace of clubs/004.jpg  ace of clubs       ace    train
# 4            0  train/ace of clubs/005.jpg  ace of clubs       ace    train

# %%
df.value_counts("data set")
# Out:
# data set
# train    7625
# test      265
# valid     265
# dtype: int64

# %%
train = df[:7630]

# %%
train.head(-5)
# Out:
#       class index                    filepaths         labels card type  \
# 0               0   train/ace of clubs/001.jpg   ace of clubs       ace
# 1               0   train/ace of clubs/002.jpg   ace of clubs       ace
# 2               0   train/ace of clubs/003.jpg   ace of clubs       ace
# 3               0   train/ace of clubs/004.jpg   ace of clubs       ace
# 4               0   train/ace of clubs/005.jpg   ace of clubs       ace
# ...           ...                          ...            ...       ...
# 7620           52  train/two of spades/151.jpg  two of spades       two
# 7621           52  train/two of spades/152.jpg  two of spades       two
# 7622           52  train/two of spades/153.jpg  two of spades       two
# 7623           52  train/two of spades/154.jpg  two of spades       two
# 7624           52  train/two of spades/155.jpg  two of spades       two
#
#      data set
# 0       train
# 1       train
# 2       train
# 3       train
# 4       train
# ...

# %%
train.value_counts("data set")
# Out:
# data set
# train    7625
# test        5
# dtype: int64

# %%
train = DataFrame({"class index": , "filepaths"})
for i, val in enumerate(df["data set"]):
  if df[i] == 'train':
