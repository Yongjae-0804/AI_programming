# %%
f = open('C:\Pro_gramming\KWU-AI-Programming\Homework\hw2_2019741045\Data.csv', 'r',encoding= 'utf-8')
#한글을 읽어오기 위한 인코딩이 필요하다. 경로는 알아서 잘
문자열 = f.read()
f.close()
print(문자열)
리스트 = list(문자열)# 바로 리스트로 캐스팅해주면 어떻게 될까요?
# Out:
# 선수명,팀명,AVG,G,PA,AB,R,H,2B,3B,HR,TB,RBI,SAC,SF
# 박건우,NC,0.346,102,431,381,50,132,18,1,10,182,59,0,3
# 이정후,키움,0.346,138,605,534,80,185,35,10,22,306,108,0,3
# 피렐라,삼성,0.342,132,591,523,95,179,27,4,26,292,102,0,2
# 이대호,롯데,0.335,136,565,519,51,174,22,0,21,259,94,0,6
# 문보경,LG,0.326,117,431,377,50,123,21,3,9,177,50,5,7
# 소크라테스,KIA,0.321,120,523,483,80,155,28,7,16,245,71,0,4
# 나성범,KIA,0.319,136,616,530,87,169,38,2,21,274,96,0,5
# 김혜성,키움,0.316,125,546,497,79,157,18,7,4,201,46,0,3
# 한동희,롯데,0.31,124,483,442,41,137,26,0,13,202,63,0,4
# 조용호,KT,0.309,123,497,443,49,137,17,3,2,166,39,2,2
# 전준우,롯데,0.306,114,494,448,70,137,30,1,11,202,67,0,9
# 최지훈,SSG,0.303,137,615,547,91,166,30,4,9,231,59,12,4
# 페르난데스,두산,0.303,131,526,485,50,147,24,0,6,189,72,0,5
# 채은성,LG,0.302,117,492,437,46,132,26,2,11,195,79,0,10
# 허경민,두산,0.294,112,459,401,56,118,23,0,6,159,57,2,6
# 박성한,SSG,0.293,133,534,464,65,136,22,4,2,172,55,6,2
# 마티니,NC,0.292,133,555,490,65,143,32,1,16,225,84,0,7
# ...

# %%
# Llist = 문자열.split('문자') 스플릿 매서드는 해당하는 문자까지
# 끊어서 리스트르 작성해준다.
Llist_1 = 문자열.split('\n') #개행문자를 기준으로 리스트가 작성된다.
print(Llist_1)
# Out:
# ['\ufeff선수명,팀명,AVG,G,PA,AB,R,H,2B,3B,HR,TB,RBI,SAC,SF', '박건우,NC,0.346,102,431,381,50,132,18,1,10,182,59,0,3', '이정후,키움,0.346,138,605,534,80,185,35,10,22,306,108,0,3', '피렐라,삼성,0.342,132,591,523,95,179,27,4,26,292,102,0,2', '이대호,롯데,0.335,136,565,519,51,174,22,0,21,259,94,0,6', '문보경,LG,0.326,117,431,377,50,123,21,3,9,177,50,5,7', '소크라테스,KIA,0.321,120,523,483,80,155,28,7,16,245,71,0,4', '나성범,KIA,0.319,136,616,530,87,169,38,2,21,274,96,0,5', '김혜성,키움,0.316,125,546,497,79,157,18,7,4,201,46,0,3', '한동희,롯데,0.31,124,483,442,41,137,26,0,13,202,63,0,4', '조용호,KT,0.309,123,497,443,49,137,17,3,2,166,39,2,2', '전준우,롯데,0.306,114,494,448,70,137,30,1,11,202,67,0,9', '최지훈,SSG,0.303,137,615,547,91,166,30,4,9,231,59,12,4', '페르난데스,두산,0.303,131,526,485,50,147,24,0,6,189,72,0,5', '채은성,LG,0.302,117,492,437,46,132,26,2,11,195,79,0,10', '허경민,두산,0.294,112,459,401,56,118,23,0,6,159,57,2,6', '박성한,SSG,0.293,133,534,464,65,136,22,4,2,172,55,6,2', '마티니,NC,0.292,133,555,490,65,143,32,1,16,225,84,0,7', '김선빈,KIA,0.29,132,5
# ...

# %%
# 리스트의 마지막 공백은 지워주시고 
# 선수명 앞에 \ufeff 는 리스트로 바꾸기전 문자열 상태에서 지워 주시고

# %%
# 새로운 리스트를 선언한뒤 for 문과 스플릿을 이용해 2차원 리스트를 만들어 줍니다.
데이타 = []
for i in Llist_1:
    데이타.append(i.split(','))
